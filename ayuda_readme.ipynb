# %%
import pandas as pd
pedidos = pd.read_excel('excel/Caleido_Pedidos_Database_prefinal.xlsm', sheet_name="Pedidos")
detalle_pedidos = pd.read_excel('excel/Caleido_Pedidos_Database_prefinal.xlsm', sheet_name="Detalle_Pedidos")
clientes = pd.read_excel('excel/Caleido_Pedidos_Database_prefinal.xlsm', sheet_name="Clientes")
print(f" tabla / hoja Pedidos\n columnas: {list(pedidos.columns)}") 
print(f" tabla / hoja Detalle_Pedidos\n columnas: {list(detalle_pedidos.columns)}") 
print(f" tabla / hoja Clientes\n columnas: {list(clientes.columns)}")
# Out:
#  tabla / hoja Pedidos
#  columnas: ['PedidoID', 'FechaPedido', 'NombreCliente', 'RazonSocial', 'RFC', 'Telefono', 'Telefono2', 'Email', 'DomicilioFiscal', 'DireccionEntrega', 'FechaEntrega', 'Estatus', 'SubtotalPedido', 'IVAPedido', 'TotalPedido']
#  tabla / hoja Detalle_Pedidos
#  columnas: ['PedidoID', 'NoProducto', 'Tecnica', 'Material', 'FechaRecepcion', 'Cantidad', 'PrecioUnitario', 'NombreLogo', 'TamanoLogo', 'Pantone', 'RutaRender', 'Observaciones', 'SubtotalProducto', 'IVAProducto', 'TotalProducto']
#  tabla / hoja Clientes
#  columnas: ['NombreCliente', 'RazonSocial', 'RFC', 'Telefono', 'Telefono2', 'Email', 'DomicilioFiscal']

# %% [markdown]
# ## Diagrama de Relación de Entidades
#
# ```mermaid
# erDiagram
#     CLIENTES {
#         string NombreCliente PK
#         string RazonSocial
#         string RFC
#         string Telefono
#         string Telefono2
#         string Email
#         string DomicilioFiscal
#     }
#
#     PEDIDOS {
#         int PedidoID PK
#         date FechaPedido
#         string NombreCliente FK
#         string RazonSocial
#         string RFC
#         string Telefono
#         string Telefono2
#         string Email
#         string DomicilioFiscal
#         string DireccionEntrega
#         date FechaEntrega
#         string Estatus
#         decimal SubtotalPedido
#         decimal IVAPedido
#         decimal TotalPedido
#     }
#
#     DETALLE_PEDIDOS {
#         int PedidoID FK
#         int NoProducto
#         string Tecnica
#         string Material
#         date FechaRecepcion
#         int Cantidad
#         decimal PrecioUnitario
#         string NombreLogo
#         string TamanoLogo
#         string Pantone
#         string RutaRender
#         string Observaciones
#         decimal SubtotalProducto
#         decimal IVAProducto
#         decimal TotalProducto
#     }
#
#     CLIENTES ||--o{ PEDIDOS : "realiza"
#     PEDIDOS ||--o{ DETALLE_PEDIDOS : "contiene"
# ```
